# %% [markdown]
# <a href="https://colab.research.google.com/github/ayaaayaaayaaayaaayaaayaa/1G3k6bk3eE5jS72tEbvvYEclhIGrEHNuA/blob/main/mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# إدخال المستخدم بشكل آمن
def get_number(message):
    while True:
        value = input(message)
        try:
            return float(value)
        except ValueError:
            print("❌ Please enter a numeric value")

quantity = get_number("Enter Quantity: ")
price = get_number("Enter Price Per Unit: ")

input_data = np.array([[quantity, price]])
prediction = model.predict(input_data)

print("💰 Expected Total sales:", round(prediction[0], 2))
# Out:
# Enter Quantity: 3
# Enter Price Per Unit: 6
# 💰 Expected Total sales: 18.03
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from google.colab import files

# قراءة البيانات)
df = pd.read_csv("/content/drive/MyDrive/Data Cleaning (B AND G)/Clean_coffee_shop_sales.csv")

# حفظ الملف الجديد
df.to_csv("mean.csv", index=False)

# تنزيله
files.download("mean.csv")
